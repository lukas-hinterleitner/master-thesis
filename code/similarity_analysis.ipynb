# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from config import get_gradient_similarity_file_path

# %%
gradient_similarities = pd.read_csv(filepath_or_buffer=get_gradient_similarity_file_path(), index_col=0)

# %%
gradient_similarities
# Out:
#                  lima_0      lima_1      lima_2      lima_3      lima_4
# original_id
# lima_0       703.829773    7.380612   26.237728    5.326746   -2.626489
# lima_1        -3.730564  197.312134   -1.583207   -5.861115   -2.444663
# lima_2        11.600008    3.029169  968.156616    7.783861   11.206284
# lima_3        11.620650    5.798673    9.425511  301.712799    0.150675
# lima_4        -4.735457    9.950832   11.523367    8.553008  390.626770

# %%
ax = plt.axes()
sns.heatmap(gradient_similarities, cmap="YlGnBu", ax=ax, annot=True)
ax.set_xlabel("paraphrased_id")

plt.show()
